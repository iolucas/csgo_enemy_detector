# %%
import os

import numpy as np
import cv2
import matplotlib.pyplot as plt
# %matplotlib inline

import tensorflow as tf

# %% [markdown]
# http://machinelearninguru.com/deep_learning/data_preparation/tfrecord/tfrecord.html

# %%
def load_img(filename):
    img = cv2.imread(filename)
    img = img[:300,:300,:3]
    return img

# %%
# %%time

imgs = np.array([load_img("imgs/" + filename) for filename in os.listdir("imgs")[:256]])
# Out:
# Wall time: 1.05 s

# %%
print(imgs.shape)
# Out:
# (10, 300, 300, 3)

# %%
img = cv2.imread("imgs/" + os.listdir("imgs")[0])
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# %%
img[:300,:300,:3].shape
# Out:
# (300, 300, 3)

# %%
img.dtype
# Out:
# dtype('uint8')

# %%
plt.imshow(np.flip(img[:300,:300,:3], axis=1))
plt.show()
plt.imshow(img[:300,:300,:3])
plt.show()
